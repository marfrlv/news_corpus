# %% [markdown]
# <a href="https://colab.research.google.com/github/marfrlv/news_corpus/blob/main/fin_cleaning_feature_ext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Data preprocessing and cleaning

# %%
# libraries
import pandas as pd
import numpy as np
import string
import re
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##1.1. Low-credibility sources

# %% [markdown]
# ### 1.1.1. Russia Today

# %%
# paths to files on drive
rt_path1 = '/content/drive/MyDrive/rt_articles.csv'
rt_path2 = '/content/drive/MyDrive/rt_articles_mar_apr.csv'

# initialize two dfs
rt_df1 = pd.read_csv(rt_path1)
rt_df2 =  pd.read_csv(rt_path2)

# concatenate two dfs
rt_df = pd.concat([rt_df1, rt_df2], axis=0)
# delete duplicates (in case if during the scraping sessions some of the articles were scraped twice)
rt_df = rt_df.drop_duplicates(subset = 'Headings')

# check if the column with articles' texts has any missing values
if rt_df['Texts'].isnull().any():
    print("Column has missing values.")
    print()
else:
    print("Column does not have missing values.")

# add the name of the source and label (1 for propaganda and 0 for not propaganda)
rt_df['Source'] = 'Russia Today'
rt_df
# Out:
# Column does not have missing values.
#                                               Headings    Publication dates  \
# 0    US' inspector general for Afghanistan warns ag...  2023-02-26 17:54:00
# 1    US presidential hopeful calls for end to Ukrai...  2023-02-26 17:11:00
# 2     Ukraine’s neighbor speaks out on NATO membership  2023-02-26 15:01:00
# 3    Defense minister explains conditions for Russi...  2023-02-26 14:26:00
# 4                   Thousands rally for peace in Italy  2023-02-26 14:25:00
# ..                                                 ...                  ...
# 295  Ukraine conflict being fueled by empires - Pop...  2023-03-10 11:32:00
# 296               Two EU members offer jets to Ukraine  2023-03-09 18:56:00
# 297         Oscars reportedly say no to Zelensky again  2023-03-09 18:56:00
# 298  US to discourage African nations from doing bu...  2023-03-09 16:41:00
# 299                 Ukrainian poultry exports flood EU  2023-03-09 14:43:00
#
#                                              Summaries  \
# 0    Failure to implement rigid oversight measures ...
# 1    The US should focus on China and Taiwan instea...
# 2    The possibility of joining NATO isn’t being ra...
# 3    Potential Russian military advances in Ukraine...
# 4    Several thousands have taken to the streets of...
# ..                                                 ...
# 295  The conflict in Ukraine is being fueled by the...
# 296  Poland and Slovakia are ready to hand over the...
# 297  Ukrainian President Vladimir Zelensky’s bid to...
# 298  Deputy Treasury Secretary Wally Adeyemo will v...
# 299  Exports of eggs and poultry from Ukraine to th...
#
#                                                  Texts        Source
# 0    Washington has been the largest financial cont...  Russia Today
# 1    Washington should focus on countering China an...  Russia Today
# 2    Moldova must be able to protect itself, but no...  Russia Today
# 3    A widening of the military operation depends o...  Russia Today
# 4    Demonstrators in the cities of Genoa and Milan...  Russia Today
# ..                                                 ...           ...
# 295  The interests of several countries, not just R...  Russia Today
# 296  Poland and Slovakia will donate Soviet-era war...  Russia Today
# 297  Ukrainian President Vladimir Zelensky’s bid to...  Russia Today
# 298  The deputy treasury secretary will attempt to ...  Russia Today
# 299  Egg exports from Ukraine have soared 1370% sin...  Russia Today
#
# [587 rows x 5 columns]

# %%
rt_texts = list(rt_df['Texts'])
print(f'There are {len(rt_texts)} in the list.')
# Out:
# There are 587 in the list.

# %% [markdown]
# ## The main function for cleaning

# %%
def clean_texts(texts_list):
    print(f'The number of texts given for cleaning {len(texts_list)}.')
    print('Processing...')
    # create an empty list to store the cleaned texts
    cleaned_list = []

    # iterate over the input
    for text in texts_list:
        # convert the text to lowercase
        text = text.lower()

        # process the text with spaCy to create a doc object
        doc = nlp(text)

        # iterate over the tokens in the doc and perform cleaning operations
        clean_tokens = []
        for token in doc:
            # remove stop words and punctuation
            if not token.is_stop and token.is_alpha:
                # lemmatize the token
                clean_tokens.append(token.lemma_)

        # join the cleaned tokens into a string and append it to the list
        clean_text = ' '.join(clean_tokens)
        cleaned_list.append(clean_text)
    print(f'The number of texts cleaned is {len(cleaned_list)}.')
    # return the cleaned list
    return cleaned_list

# %%
# extract content words
rt_cleaned = clean_texts(rt_texts)
# delete the name of the source
rt_cleaned_fin = []
for text in rt_cleaned:
  text_wo_source_name = re.sub('russia today', '', text)
  rt_cleaned_fin.append(text_wo_source_name)
# Out:
# The number of texts given for cleaning 587.
# Processing...
# The number of texts cleaned is 587.

# %%
rt_df['Content words'] = rt_cleaned_fin
rt_df
# Out:
#                                               Headings    Publication dates  \
# 0    US' inspector general for Afghanistan warns ag...  2023-02-26 17:54:00
# 1    US presidential hopeful calls for end to Ukrai...  2023-02-26 17:11:00
# 2     Ukraine’s neighbor speaks out on NATO membership  2023-02-26 15:01:00
# 3    Defense minister explains conditions for Russi...  2023-02-26 14:26:00
# 4                   Thousands rally for peace in Italy  2023-02-26 14:25:00
# ..                                                 ...                  ...
# 295  Ukraine conflict being fueled by empires - Pop...  2023-03-10 11:32:00
# 296               Two EU members offer jets to Ukraine  2023-03-09 18:56:00
# 297         Oscars reportedly say no to Zelensky again  2023-03-09 18:56:00
# 298  US to discourage African nations from doing bu...  2023-03-09 16:41:00
# 299                 Ukrainian poultry exports flood EU  2023-03-09 14:43:00
#
#                                              Summaries  \
# 0    Failure to implement rigid oversight measures ...
# 1    The US should focus on China and Taiwan instea...
# 2    The possibility of joining NATO isn’t being ra...
# 3    Potential Russian military advances in Ukraine...
# 4    Several thousands have taken to the streets of...
# ..                                                 ...
# 295  The conflict in Ukraine is being fueled by the...
# 296  Poland and Slovakia are ready to hand over the...
# 297  Ukrainian President Vladimir Zelensky’s bid to...
# 298  Deputy Treasury Secretary Wally Adeyemo will v...
# 299  Exports of eggs and poultry from Ukraine to th...
#
#                                                  Texts        Source  \
# 0    Washington has been the largest financial cont...  Russia Today
# 1    Washington should focus on countering China an...  Russia Today
# 2    Moldova must be able to protect itself, but no...  Russia Today
# 3    A widening of the military operation depends o...  Russia Today
# 4    Demonstrators in the cities of Genoa and Milan...  Russia Today
# ..                                                 ...           ...
# 295  The interests of several countries, not just R...  Russia Today
# 296  Poland and Slovakia will donate Soviet-era war...  Russia Today
# 297  Ukrainian President Vladimir Zelensky’s bid to...  Russia Today
# 298  The deputy treasury secretary will attempt to ...  Russia Today
# 299  Egg exports from Ukraine have soared 1370% sin...  Russia Today
#
#                                          Content words
# 0    washington large financial contributor ukraine...
# 1    washington focus counter china tackle taiwan i...
# 2    moldova able protect join lead military bloc p...
# 3    widening military operation depend weaponry ki...
# 4    demonstrator city genoa milan demand end weapo...
# ..                                                 ...
# 295  interest country russia drive hostility pontif...
# 296  poland slovakia donate soviet era warplane kie...
# 297  ukrainian president vladimir zelensky bid appe...
# 298  deputy treasury secretary attempt pressure sta...
# 299  egg export ukraine soar bloc remove trade rest...
#
# [587 rows x 6 columns]

# %% [markdown]
# ### 1.1.2. TASS

# %%
path = '/content/drive/MyDrive/tass_articles.csv'
tass_df = pd.read_csv(path)
tass_df = tass_df.drop_duplicates(subset = 'Headings')
if rt_df['Texts'].isnull().any():
    print("Column has missing values.")
    print()
else:
    print("Column does not have missing values.")
tass_df['Source'] = 'TASS'
tass_df
# Out:
# Column does not have missing values.
#                                                Headings  \
# 0     Russia calls for preventing large-scale Palest...
# 1     Switzerland drops neutrality to support Ukrain...
# 2     US, EU seeking to divert int’l community’s att...
# 27    US is ‘confident’ China is considering supplie...
# 28    Washington’s ‘peace narrative’ illusory due to...
# ...                                                 ...
# 1442  Arms supplies to Ukraine pushes Kiev toward mi...
# 1443  Zelensky's statements mean he is not going to ...
# 1444               Talks begin between Putin and Macron
# 1445  Putin plans to hold another telephone conversa...
# 1446  US has ‘very concrete ideas’ on European secur...
#
#              Publication dates  \
# 0         MOSCOW, February 26.
# 1         MOSCOW, February 26.
# 2         MOSCOW, February 26.
# 27    WASHINGTON, February 26.
# 28       BEIJING, February 25.
# ...                        ...
# 1442      MOSCOW, February 20.
# 1443      MOSCOW, February 20.
# 1444      MOSCOW, February 20.
# 1445      MOSCOW, February 20.
# 1446      MUNICH, February 20.
#
#                                               Summaries  \
# 0     Hindering the Quartet’s activities adversely i...
# 1     Apart from that, she drew attention to the fac...
# 2     He stressed that Moscow deems such an approach...
# 27    The US leadership thought it was "important to...
# 28    According to the article, the West regards its...
# ...                                                 ...
# 1442  It was the fifth telephone contact between the...
# 1443  Dmitry Peskov stressed that the settlement in ...
# 1444  The Elysee Palace noted that today's conversat...
# 1445  Macron reportedly intends to discuss aggravati...
# 1446  US Secretary of State said that his meeting wi...
#
#                                                   Texts Source
# 0     MOSCOW, February 26. /TASS/. Russia calls for ...   TASS
# 1     MOSCOW, February 26. /TASS/. Bern has dropped ...   TASS
# 2     MOSCOW, February 26. /TASS/. The United States...   TASS
# 27    WASHINGTON, February 26. /TASS/. The US is con...   TASS
# 28    BEIJING, February 25. /TASS/. American claims ...   TASS
# ...                                                 ...    ...
# 1442  MOSCOW, February 20. /TASS/. Russian President...   TASS
# 1443  MOSCOW, February 20. /TASS/. Statements by Ukr...   TASS
# 1444  MOSCOW, February 20. /TASS/. The telephone con...   TASS
# 1445  MOSCOW, February 20. /TASS/. On Sunday, Russia...   TASS
# 1446  MUNICH, February 20. /TASS/. In the light of h...   TASS
#
# [1421 rows x 5 columns]

# %%
tass_texts = list(tass_df['Texts'])
print(f'There are {len(tass_texts)} in the list.')
# Out:
# There are 1421 in the list.

# %%
# extract content words
tass_cleaned = clean_texts(tass_texts)
# delete the name of the source
tass_cleaned_fin = []
for text in tass_cleaned:
  text_wo_source_name = re.sub('tass', '', text)
  tass_cleaned_fin.append(text_wo_source_name)
# Out:
# The number of texts given for cleaning 1421.
# Processing...
# The number of texts cleaned is 1421.

# %%
tass_df['Content words'] = tass_cleaned_fin
tass_df
# Out:
#                                                Headings  \
# 0     Russia calls for preventing large-scale Palest...
# 1     Switzerland drops neutrality to support Ukrain...
# 2     US, EU seeking to divert int’l community’s att...
# 27    US is ‘confident’ China is considering supplie...
# 28    Washington’s ‘peace narrative’ illusory due to...
# ...                                                 ...
# 1442  Arms supplies to Ukraine pushes Kiev toward mi...
# 1443  Zelensky's statements mean he is not going to ...
# 1444               Talks begin between Putin and Macron
# 1445  Putin plans to hold another telephone conversa...
# 1446  US has ‘very concrete ideas’ on European secur...
#
#              Publication dates  \
# 0         MOSCOW, February 26.
# 1         MOSCOW, February 26.
# 2         MOSCOW, February 26.
# 27    WASHINGTON, February 26.
# 28       BEIJING, February 25.
# ...                        ...
# 1442      MOSCOW, February 20.
# 1443      MOSCOW, February 20.
# 1444      MOSCOW, February 20.
# 1445      MOSCOW, February 20.
# 1446      MUNICH, February 20.
#
#                                               Summaries  \
# 0     Hindering the Quartet’s activities adversely i...
# 1     Apart from that, she drew attention to the fac...
# 2     He stressed that Moscow deems such an approach...
# 27    The US leadership thought it was "important to...
# 28    According to the article, the West regards its...
# ...                                                 ...
# 1442  It was the fifth telephone contact between the...
# 1443  Dmitry Peskov stressed that the settlement in ...
# 1444  The Elysee Palace noted that today's conversat...
# 1445  Macron reportedly intends to discuss aggravati...
# 1446  US Secretary of State said that his meeting wi...
#
#                                                   Texts Source  \
# 0     MOSCOW, February 26. /TASS/. Russia calls for ...   TASS
# 1     MOSCOW, February 26. /TASS/. Bern has dropped ...   TASS
# 2     MOSCOW, February 26. /TASS/. The United States...   TASS
# 27    WASHINGTON, February 26. /TASS/. The US is con...   TASS
# 28    BEIJING, February 25. /TASS/. American claims ...   TASS
# ...                                                 ...    ...
# 1442  MOSCOW, February 20. /TASS/. Russian President...   TASS
# 1443  MOSCOW, February 20. /TASS/. Statements by Ukr...   TASS
# 1444  MOSCOW, February 20. /TASS/. The telephone con...   TASS
# 1445  MOSCOW, February 20. /TASS/. On Sunday, Russia...   TASS
# 1446  MUNICH, February 20. /TASS/. In the light of h...   TASS
#
#                                           Content words
# 0     moscow february russia call resume work middle...
# 1     moscow february bern drop traditional neutrali...
# 2     moscow february united states european union s...
# 27    washington february confident china consider s...
# 28    beijing february american claim importance glo...
# ...                                                 ...
# 1442  moscow february russian president vladimir put...
# 1443  moscow february statement ukrainian president ...
# 1444  moscow february telephone conversation russian...
# 1445  moscow february sunday russian president vladi...
# 1446  munich february light upcoming meeting russian...
#
# [1421 rows x 6 columns]

# %% [markdown]
# ### 1.1.3 News Target

# %%
path = '/content/drive/MyDrive/news_target_articles.csv'
nt_df = pd.read_csv(path)
nt_df = nt_df.drop_duplicates(subset = 'Headings')
if nt_df['Texts'].isnull().any():
    print("Column has missing values.")
    print()
else:
    print("Column does not have missing values.")
nt_df['Source'] = 'News Target'
nt_df
# Out:
# Column does not have missing values.
#                                                Headings    Publication dates  \
# 0     Worldwide famine looms as Russia-Ukraine confl...  2022-06-08 00:43:36
# 1     Will the Russia-Ukraine conflict end with the ...  2022-03-11 12:38:31
# 2     Ongoing Russia-Ukraine conflict pushing global...  2022-05-08 20:55:29
# 3     Russia-Ukraine conflict not helping American c...  2022-05-08 20:55:39
# 4     Nebraska farmland values climb 16%, but farmer...  2022-05-06 12:48:36
# ...                                                 ...                  ...
# 1431  Biden intentionally destroying U.S. economy an...  2022-09-09 21:19:37
# 1432  USA targeting of Moskva ship is Russia’s “Pear...  2022-04-21 13:41:48
# 1433  Democrats rooting for Ukraine to beat back Rus...  2022-03-02 00:32:07
# 1434  US lags behind Russia, China in hypersonic wea...  2022-03-14 10:43:43
# 1435  Ukraine’s defense minister claims his country ...  2023-01-17 00:26:48
#
#                                               Summaries  \
# 0     An article published by British weekly newspap...
# 1     Rumors are emerging to suggest that the endgam...
# 2     The ongoing conflict between Russia and Ukrain...
# 3     The United States has spent the past two years...
# 4     The value of farmland in Nebraska has hit hist...
# ...                                                 ...
# 1431  It’s become patently obvious that Joe Biden’s ...
# 1432  To understand the sinking of the Moskva and Pu...
# 1433  If Democrats are anything, they are massive hy...
# 1434  The United States has fallen behind Russia and...
# 1435  Ukraine’s minister of defense claimed in a rec...
#
#                                                   Texts       Source
# 0     Worldwide famine looms as Russia-Ukraine confl...  News Target
# 1     Will the Russia-Ukraine conflict end with the ...  News Target
# 2     Ongoing Russia-Ukraine conflict pushing global...  News Target
# 3     Russia-Ukraine conflict not helping American c...  News Target
# 4     Nebraska farmland values climb 16%, but farmer...  News Target
# ...                                                 ...          ...
# 1431  Biden intentionally destroying U.S. economy an...  News Target
# 1432  USA targeting of Moskva ship is Russia’s “Pear...  News Target
# 1433  Democrats rooting for Ukraine to beat back Rus...  News Target
# 1434  Report: US lags behind Russia, China in hypers...  News Target
# 1435  Ukraine’s defense minister claims his country ...  News Target
#
# [1436 rows x 5 columns]

# %%
# in all articles from News Target there are lists of sources used in the end, the code below allows to get rid of them
nt_texts = nt_df['Texts']
nt_texts_wo_sources = []
for text in nt_texts:
  nt_text_wo_sources = text.split('Sources')[0]
  nt_texts_wo_sources.append(nt_text_wo_sources)

# to control
print(len(nt_texts_wo_sources))
# Out:
# 1436

# %%
# for cleaning use the list with texts WITHOUT SOURCES!
# extract content words
nt_cleaned = clean_texts(nt_texts_wo_sources)
# delete the name of the source
nt_cleaned_fin = []
for text in nt_cleaned:
  text_wo_source_name = re.sub('news target', '', text)
  nt_cleaned_fin.append(text_wo_source_name)
# Out:
# The number of texts given for cleaning 1436.
# Processing...
# The number of texts cleaned is 1436.

# %%
nt_df['Content words'] = nt_cleaned_fin
nt_df
# Out:
#                                                Headings    Publication dates  \
# 0     Worldwide famine looms as Russia-Ukraine confl...  2022-06-08 00:43:36
# 1     Will the Russia-Ukraine conflict end with the ...  2022-03-11 12:38:31
# 2     Ongoing Russia-Ukraine conflict pushing global...  2022-05-08 20:55:29
# 3     Russia-Ukraine conflict not helping American c...  2022-05-08 20:55:39
# 4     Nebraska farmland values climb 16%, but farmer...  2022-05-06 12:48:36
# ...                                                 ...                  ...
# 1431  Biden intentionally destroying U.S. economy an...  2022-09-09 21:19:37
# 1432  USA targeting of Moskva ship is Russia’s “Pear...  2022-04-21 13:41:48
# 1433  Democrats rooting for Ukraine to beat back Rus...  2022-03-02 00:32:07
# 1434  US lags behind Russia, China in hypersonic wea...  2022-03-14 10:43:43
# 1435  Ukraine’s defense minister claims his country ...  2023-01-17 00:26:48
#
#                                               Summaries  \
# 0     An article published by British weekly newspap...
# 1     Rumors are emerging to suggest that the endgam...
# 2     The ongoing conflict between Russia and Ukrain...
# 3     The United States has spent the past two years...
# 4     The value of farmland in Nebraska has hit hist...
# ...                                                 ...
# 1431  It’s become patently obvious that Joe Biden’s ...
# 1432  To understand the sinking of the Moskva and Pu...
# 1433  If Democrats are anything, they are massive hy...
# 1434  The United States has fallen behind Russia and...
# 1435  Ukraine’s minister of defense claimed in a rec...
#
#                                                   Texts       Source  \
# 0     Worldwide famine looms as Russia-Ukraine confl...  News Target
# 1     Will the Russia-Ukraine conflict end with the ...  News Target
# 2     Ongoing Russia-Ukraine conflict pushing global...  News Target
# 3     Russia-Ukraine conflict not helping American c...  News Target
# 4     Nebraska farmland values climb 16%, but farmer...  News Target
# ...                                                 ...          ...
# 1431  Biden intentionally destroying U.S. economy an...  News Target
# 1432  USA targeting of Moskva ship is Russia’s “Pear...  News Target
# 1433  Democrats rooting for Ukraine to beat back Rus...  News Target
# 1434  Report: US lags behind Russia, China in hypers...  News Target
# 1435  Ukraine’s defense minister claims his country ...  News Target
#
#                                           Content words
# 0     worldwide famine loom russia ukraine conflict ...
# 1     russia ukraine conflict end collapse western c...
# 2     ongoing russia ukraine conflict push global ec...
# 3     russia ukraine conflict help american company ...
# 4     nebraska farmland value climb farmer worry eff...
# ...                                                 ...
# 1431  biden intentionally destroy economy sabotage a...
# 1432  usa target moskva ship russia pearl harbor ret...
# 1433  democrats root ukraine beat russian invasion s...
# 1434  report lag russia china hypersonic weapon race...
# 1435  ukraine defense minister claim country de fact...
#
# [1436 rows x 6 columns]

# %% [markdown]
# ### 1.1.4. Activist Post

# %%
path = '/content/drive/MyDrive/activist_post_articles.csv'
ap_df = pd.read_csv(path)
ap_df = ap_df.drop_duplicates(subset = 'Headings')
if ap_df['Texts'].isnull().any():
    print("Column has missing values.")
    print()
else:
    print("Column does not have missing values.")
ap_df['Source'] = 'Activist Post'
ap_df
# Out:
# Column does not have missing values.
#                                               Headings    Publication dates  \
# 0    What Happens Next In The Ukraine Proxy War? A ...  2023-02-17 13:08:27
# 1    Zelensky Signs Agreement With JPMorgan on Ukra...  2023-02-15 01:51:43
# 2    Canada’s Dangerous Escalation in the Russia-Uk...  2023-02-11 16:22:33
# 3    Russia Says The U.S. Has “Questions to Answer”...  2023-02-09 17:15:32
# 4    New $2.2 Billion Arms Package for Ukraine Incl...  2023-02-06 15:50:04
# ..                                                 ...                  ...
# 114  100+ Anti-War Groups Demand Biden End Brinkman...  2022-02-01 14:14:44
# 115  Washington Plans Fresh Sanctions on Russia, Ke...  2023-02-20 11:57:07
# 116         How Much Is US Aid to Ukraine Costing You?  2023-02-19 00:39:42
# 117  Flashback: Rick Rozoff Warns Ukraine War is In...  2023-02-18 17:15:05
# 118  DC Rally Feb 19: Rage Against The War Machine ...  2023-02-17 18:35:25
#
#                                              Summaries  \
# 0    The Ukraine event is just one part of a larger...
# 1    JPMorgan, America’s largest bank, discussed wi...
# 2    Unless Canada distances itself from this war f...
# 3    The Central Intelligence Agency and the White ...
# 4    According to the Pentagon fact sheet, the US h...
# ..                                                 ...
# 114                                                NaN
# 115  The sanctions’ targets include Russia’s financ...
# 116  The amount is piling up, and it's a lot to pay...
# 117  Rozoff warns that war is not a potential outco...
# 118                                                NaN
#
#                                                  Texts         Source
# 0    By Brandon Smith\nFrom the very beginning of t...  Activist Post
# 1    By Dave DeCamp\nBankers from JPMorgan Chase vi...  Activist Post
# 2    Op-Ed by Dan Fournier\nKey Takeaways:\nCanada ...  Activist Post
# 3    By Mac Slavo\nRussia says the United States ha...  Activist Post
# 4    By Dave DeCamp\nThe Biden administration on Fr...  Activist Post
# ..                                                 ...            ...
# 114  By Jake Johnson\nMore than 100 advocacy organi...  Activist Post
# 115  By Connor Freeman\nThe White House is readying...  Activist Post
# 116  By David R. Henderson\nIn 2022, the U.S. gover...  Activist Post
# 117  By The Corbett Report\nRick Rozoff of Stop NAT...  Activist Post
# 118  By Neenah Payne\nFeb. 19: We Need a Huge Rage ...  Activist Post
#
# [117 rows x 5 columns]

# %%
# get rid of authors' names at the beginning as well as from all the information on how to support them
ap_texts = ap_df['Texts']
ap_texts_for_cleaning = []

for text in ap_texts:
  act_p_text_wo_name = text.split('\n', 1)[1]
  act_p_text_wo_info = act_p_text_wo_name.split('Become a Patron!')[0]

  # use this as an input for the cleaning function!
  ap_texts_for_cleaning.append(act_p_text_wo_info)

print(len(ap_texts_for_cleaning))
# Out:
# 117

# %%
# for cleaning use the list with texts WITHOUT AUTHORS' NAMES AND INFO ON HOW TO SUPPORT!
# extract content words
ap_cleaned = clean_texts(ap_texts_for_cleaning)
# delete the name of the source
ap_cleaned_fin = []
for text in ap_cleaned:
  text_wo_source_name = re.sub('activist post', '', text)
  ap_cleaned_fin.append(text_wo_source_name)
# Out:
# The number of texts given for cleaning 117.
# Processing...
# The number of texts cleaned is 117.

# %%
ap_df['Content words'] = ap_cleaned_fin
ap_df
# Out:
#                                               Headings    Publication dates  \
# 0    What Happens Next In The Ukraine Proxy War? A ...  2023-02-17 13:08:27
# 1    Zelensky Signs Agreement With JPMorgan on Ukra...  2023-02-15 01:51:43
# 2    Canada’s Dangerous Escalation in the Russia-Uk...  2023-02-11 16:22:33
# 3    Russia Says The U.S. Has “Questions to Answer”...  2023-02-09 17:15:32
# 4    New $2.2 Billion Arms Package for Ukraine Incl...  2023-02-06 15:50:04
# ..                                                 ...                  ...
# 114  100+ Anti-War Groups Demand Biden End Brinkman...  2022-02-01 14:14:44
# 115  Washington Plans Fresh Sanctions on Russia, Ke...  2023-02-20 11:57:07
# 116         How Much Is US Aid to Ukraine Costing You?  2023-02-19 00:39:42
# 117  Flashback: Rick Rozoff Warns Ukraine War is In...  2023-02-18 17:15:05
# 118  DC Rally Feb 19: Rage Against The War Machine ...  2023-02-17 18:35:25
#
#                                              Summaries  \
# 0    The Ukraine event is just one part of a larger...
# 1    JPMorgan, America’s largest bank, discussed wi...
# 2    Unless Canada distances itself from this war f...
# 3    The Central Intelligence Agency and the White ...
# 4    According to the Pentagon fact sheet, the US h...
# ..                                                 ...
# 114                                                NaN
# 115  The sanctions’ targets include Russia’s financ...
# 116  The amount is piling up, and it's a lot to pay...
# 117  Rozoff warns that war is not a potential outco...
# 118                                                NaN
#
#                                                  Texts         Source  \
# 0    By Brandon Smith\nFrom the very beginning of t...  Activist Post
# 1    By Dave DeCamp\nBankers from JPMorgan Chase vi...  Activist Post
# 2    Op-Ed by Dan Fournier\nKey Takeaways:\nCanada ...  Activist Post
# 3    By Mac Slavo\nRussia says the United States ha...  Activist Post
# 4    By Dave DeCamp\nThe Biden administration on Fr...  Activist Post
# ..                                                 ...            ...
# 114  By Jake Johnson\nMore than 100 advocacy organi...  Activist Post
# 115  By Connor Freeman\nThe White House is readying...  Activist Post
# 116  By David R. Henderson\nIn 2022, the U.S. gover...  Activist Post
# 117  By The Corbett Report\nRick Rozoff of Stop NAT...  Activist Post
# 118  By Neenah Payne\nFeb. 19: We Need a Huge Rage ...  Activist Post
#
#                                          Content words
# 0    beginning ukraine conflict follow development ...
# 1    banker jpmorgan chase visit ukraine week sign ...
# 2    key takeaway canada deceptively manipulate sup...
# 3    russia say united states question answer pipel...
# 4    biden administration friday announce new billi...
# ..                                                 ...
# 114  advocacy organization represent million people...
# 115  white house ready raft new sanction export con...
# 116  government approve expenditure billion aid ukr...
# 117  rick rozoff stop nato join context nato eu imf...
# 118  feb need huge rage war machine rick sterling a...
#
# [117 rows x 6 columns]

# %% [markdown]
# ## 1.1.5. Low-credibility sources dataset

# %%
# concatenate all dfs
lc_df = pd.concat([rt_df, tass_df, ap_df, nt_df])
if lc_df['Content words'].isnull().any():
    print("Column has missing values.")
    print()
else:
    print("Column does not have missing values.")
lc_df
# Out:
# Column does not have missing values.
#                                                Headings    Publication dates  \
# 0     US' inspector general for Afghanistan warns ag...  2023-02-26 17:54:00
# 1     US presidential hopeful calls for end to Ukrai...  2023-02-26 17:11:00
# 2      Ukraine’s neighbor speaks out on NATO membership  2023-02-26 15:01:00
# 3     Defense minister explains conditions for Russi...  2023-02-26 14:26:00
# 4                    Thousands rally for peace in Italy  2023-02-26 14:25:00
# ...                                                 ...                  ...
# 1431  Biden intentionally destroying U.S. economy an...  2022-09-09 21:19:37
# 1432  USA targeting of Moskva ship is Russia’s “Pear...  2022-04-21 13:41:48
# 1433  Democrats rooting for Ukraine to beat back Rus...  2022-03-02 00:32:07
# 1434  US lags behind Russia, China in hypersonic wea...  2022-03-14 10:43:43
# 1435  Ukraine’s defense minister claims his country ...  2023-01-17 00:26:48
#
#                                               Summaries  \
# 0     Failure to implement rigid oversight measures ...
# 1     The US should focus on China and Taiwan instea...
# 2     The possibility of joining NATO isn’t being ra...
# 3     Potential Russian military advances in Ukraine...
# 4     Several thousands have taken to the streets of...
# ...                                                 ...
# 1431  It’s become patently obvious that Joe Biden’s ...
# 1432  To understand the sinking of the Moskva and Pu...
# 1433  If Democrats are anything, they are massive hy...
# 1434  The United States has fallen behind Russia and...
# 1435  Ukraine’s minister of defense claimed in a rec...
#
#                                                   Texts        Source  \
# 0     Washington has been the largest financial cont...  Russia Today
# 1     Washington should focus on countering China an...  Russia Today
# 2     Moldova must be able to protect itself, but no...  Russia Today
# 3     A widening of the military operation depends o...  Russia Today
# 4     Demonstrators in the cities of Genoa and Milan...  Russia Today
# ...                                                 ...           ...
# 1431  Biden intentionally destroying U.S. economy an...   News Target
# 1432  USA targeting of Moskva ship is Russia’s “Pear...   News Target
# 1433  Democrats rooting for Ukraine to beat back Rus...   News Target
# 1434  Report: US lags behind Russia, China in hypers...   News Target
# 1435  Ukraine’s defense minister claims his country ...   News Target
#
#                                           Content words
# 0     washington large financial contributor ukraine...
# 1     washington focus counter china tackle taiwan i...
# 2     moldova able protect join lead military bloc p...
# 3     widening military operation depend weaponry ki...
# 4     demonstrator city genoa milan demand end weapo...
# ...                                                 ...
# 1431  biden intentionally destroy economy sabotage a...
# 1432  usa target moskva ship russia pearl harbor ret...
# 1433  democrats root ukraine beat russian invasion s...
# 1434  report lag russia china hypersonic weapon race...
# 1435  ukraine defense minister claim country de fact...
#
# [3561 rows x 6 columns]

# %%
lc_df['Label'] = 1
lc_df
# Out:
#                                                Headings    Publication dates  \
# 0     US' inspector general for Afghanistan warns ag...  2023-02-26 17:54:00
# 1     US presidential hopeful calls for end to Ukrai...  2023-02-26 17:11:00
# 2      Ukraine’s neighbor speaks out on NATO membership  2023-02-26 15:01:00
# 3     Defense minister explains conditions for Russi...  2023-02-26 14:26:00
# 4                    Thousands rally for peace in Italy  2023-02-26 14:25:00
# ...                                                 ...                  ...
# 1431  Biden intentionally destroying U.S. economy an...  2022-09-09 21:19:37
# 1432  USA targeting of Moskva ship is Russia’s “Pear...  2022-04-21 13:41:48
# 1433  Democrats rooting for Ukraine to beat back Rus...  2022-03-02 00:32:07
# 1434  US lags behind Russia, China in hypersonic wea...  2022-03-14 10:43:43
# 1435  Ukraine’s defense minister claims his country ...  2023-01-17 00:26:48
#
#                                               Summaries  \
# 0     Failure to implement rigid oversight measures ...
# 1     The US should focus on China and Taiwan instea...
# 2     The possibility of joining NATO isn’t being ra...
# 3     Potential Russian military advances in Ukraine...
# 4     Several thousands have taken to the streets of...
# ...                                                 ...
# 1431  It’s become patently obvious that Joe Biden’s ...
# 1432  To understand the sinking of the Moskva and Pu...
# 1433  If Democrats are anything, they are massive hy...
# 1434  The United States has fallen behind Russia and...
# 1435  Ukraine’s minister of defense claimed in a rec...
#
#                                                   Texts        Source  \
# 0     Washington has been the largest financial cont...  Russia Today
# 1     Washington should focus on countering China an...  Russia Today
# 2     Moldova must be able to protect itself, but no...  Russia Today
# 3     A widening of the military operation depends o...  Russia Today
# 4     Demonstrators in the cities of Genoa and Milan...  Russia Today
# ...                                                 ...           ...
# 1431  Biden intentionally destroying U.S. economy an...   News Target
# 1432  USA targeting of Moskva ship is Russia’s “Pear...   News Target
# 1433  Democrats rooting for Ukraine to beat back Rus...   News Target
# 1434  Report: US lags behind Russia, China in hypers...   News Target
# 1435  Ukraine’s defense minister claims his country ...   News Target
#
#                                           Content words  Label
# 0     washington large financial contributor ukraine...      1
# 1     washington focus counter china tackle taiwan i...      1
# 2     moldova able protect join lead military bloc p...      1
# 3     widening military operation depend weaponry ki...      1
# 4     demonstrator city genoa milan demand end weapo...      1
# ...                                                 ...    ...
# 1431  biden intentionally destroy economy sabotage a...      1
# 1432  usa target moskva ship russia pearl harbor ret...      1
# 1433  democrats root ukraine beat russian invasion s...      1
# 1434  report lag russia china hypersonic weapon race...      1
# 1435  ukraine defense minister claim country de fact...      1
#
# [3561 rows x 7 columns]

# %% [markdown]
# ## 1.2. High-credibility sources

# %% [markdown]
# ### 1.2.1. Foreign Policy

# %%
path = '/content/drive/MyDrive/for_pol_articles.csv'
fp_df = pd.read_csv(path)
fp_df = fp_df.drop_duplicates(subset = 'Headings')
if fp_df['Texts'].isnull().any():
    print("Column has missing values.")
    print()
else:
    print("Column does not have missing values.")
fp_df['Source'] = 'Foreign Policy'
fp_df
# Out:
# Column does not have missing values.
#                                                Headings    Publication dates  \
# 0       China’s Taiwan Saber-Rattling Is the New Normal  2022-08-05 15:24:45
# 1                        A Realist Guide to World Peace  2022-12-23 08:04:45
# 2     In Northern Kosovo, Tensions Threaten to Boil ...  2022-10-31 10:15:27
# 3     How Egypt Doubled Down on Fossil Fuels by Stif...  2022-11-08 18:14:35
# 4                           Who Owns the Earth’s Lungs?  2022-12-09 06:00:12
# ...                                                 ...                  ...
# 2288  Polish MiG-29 Jets for Ukraine Is a Deeply Fla...  2022-03-14 15:19:10
# 2289          Russia and China Threats Are Not the Same  2022-10-13 15:44:14
# 2290  How Europe Can Slash Fossil Fuels and Frustrat...  2022-03-10 09:39:12
# 2291     Moscow Strikes Back at Countries That Cross It  2022-04-18 13:15:20
# 2292                                 The Scots Question  2022-06-29 14:47:21
#
#       Summaries                                              Texts  \
# 0           NaN  Experts who spoke to Foreign Policy said the m...
# 1           NaN  For a realist like me, these developments aren...
# 2           NaN  Underlying issues, however, remain unresolved....
# 3           NaN  But the undeniable failures of high-emission c...
# 4           NaN  The research station, called Camp 41, is a pin...
# ...         ...                                                ...
# 2288        NaN  Successful security assistance begins with an ...
# 2289        NaN  If you would like to receive Situation Report ...
# 2290        NaN  Yet, in the first two weeks of Russia’s invasi...
# 2291        NaN  “Mr. President, we are sure that today’s speak...
# 2292        NaN  That Scots is so embedded in everyday communic...
#
#               Source
# 0     Foreign Policy
# 1     Foreign Policy
# 2     Foreign Policy
# 3     Foreign Policy
# 4     Foreign Policy
# ...              ...
# 2288  Foreign Policy
# 2289  Foreign Policy
# 2290  Foreign Policy
# 2291  Foreign Policy
# 2292  Foreign Policy
#
# [2064 rows x 5 columns]

# %%
fp_texts = list(fp_df['Texts'])
print(f'There are {len(fp_texts)} in the list.')
# Out:
# There are 2064 in the list.

# %%
# for cleaning use the list with texts WITHOUT AUTHORS' NAMES AND INFO ON HOW TO SUPPORT!
# extract content words
fp_cleaned = clean_texts(fp_texts)
# delete the name of the source
fp_cleaned_fin = []
for text in fp_cleaned:
  text_wo_source_name = re.sub('foreign policy', '', text)
  fp_cleaned_fin.append(text_wo_source_name)
# Out:
# The number of texts given for cleaning 2064.
# Processing...
# The number of texts cleaned is 2064.

# %%
fp_df['Content words'] = fp_cleaned_fin
fp_df
# Out:
#                                                Headings    Publication dates  \
# 0       China’s Taiwan Saber-Rattling Is the New Normal  2022-08-05 15:24:45
# 1                        A Realist Guide to World Peace  2022-12-23 08:04:45
# 2     In Northern Kosovo, Tensions Threaten to Boil ...  2022-10-31 10:15:27
# 3     How Egypt Doubled Down on Fossil Fuels by Stif...  2022-11-08 18:14:35
# 4                           Who Owns the Earth’s Lungs?  2022-12-09 06:00:12
# ...                                                 ...                  ...
# 2288  Polish MiG-29 Jets for Ukraine Is a Deeply Fla...  2022-03-14 15:19:10
# 2289          Russia and China Threats Are Not the Same  2022-10-13 15:44:14
# 2290  How Europe Can Slash Fossil Fuels and Frustrat...  2022-03-10 09:39:12
# 2291     Moscow Strikes Back at Countries That Cross It  2022-04-18 13:15:20
# 2292                                 The Scots Question  2022-06-29 14:47:21
#
#       Summaries                                              Texts  \
# 0           NaN  Experts who spoke to Foreign Policy said the m...
# 1           NaN  For a realist like me, these developments aren...
# 2           NaN  Underlying issues, however, remain unresolved....
# 3           NaN  But the undeniable failures of high-emission c...
# 4           NaN  The research station, called Camp 41, is a pin...
# ...         ...                                                ...
# 2288        NaN  Successful security assistance begins with an ...
# 2289        NaN  If you would like to receive Situation Report ...
# 2290        NaN  Yet, in the first two weeks of Russia’s invasi...
# 2291        NaN  “Mr. President, we are sure that today’s speak...
# 2292        NaN  That Scots is so embedded in everyday communic...
#
#               Source                                      Content words
# 0     Foreign Policy  expert speak  say move indicate china try set ...
# 1     Foreign Policy  realist like development surprising realism ce...
# 2     Foreign Policy  underlie issue remain unresolved particularly ...
# 3     Foreign Policy  undeniable failure high emission country allev...
# 4     Foreign Policy  research station call camp pinprick civilizati...
# ...              ...                                                ...
# 2288  Foreign Policy  successful security assistance begin identify ...
# 2289  Foreign Policy  like receive situation report inbox thursday s...
# 2290  Foreign Policy  week russia invasion ukraine eu likely pay upw...
# 2291  Foreign Policy  mr president sure today speaker address lot ki...
# 2292  Foreign Policy  scot embed everyday communication give rise co...
#
# [2064 rows x 6 columns]

# %% [markdown]
# ### 1.2.2. Associated Press

# %%
path = '/content/drive/MyDrive/ass_press_articles.csv'
asp_df = pd.read_csv(path)
asp_df = asp_df.drop_duplicates(subset = 'Headings')
if asp_df['Texts'].isnull().any():
    print("Column has missing values.")
    print()
else:
    print("Column does not have missing values.")
asp_df['Source'] = 'Associated Press'
asp_df
# Out:
# Column has missing values.
#                                              Headings    Publication dates  \
# 0   Word war: In Russia-Ukraine war, information b...  2023-02-23 05:07:51
# 1   Putin's Ukraine gamble seen as biggest threat ...  2023-02-20 07:43:46
# 2   Yellen visits Ukraine, underscores US economic...  2023-02-27 17:52:46
# 3   G-20 meeting in India ends without consensus o...  2023-02-25 13:27:54
# 4   Japan, other G-7 leaders step up Russia sanctions  2023-02-24 12:43:36
# ..                                                ...                  ...
# 66  Ukraine: Drone video shows cost of intense fig...  2023-02-24 08:44:03
# 67  Russia's sports exile persists 1 year after in...  2023-02-22 14:26:09
# 68  Ukraine war saga unfolds across the lives of 5...  2023-02-16 08:30:40
# 69  Russian delegates defiant at hostile OSCE asse...  2023-02-24 21:03:56
# 70  Met Opera marks 1st year of Ukraine war with c...  2023-02-25 16:36:03
#
#                                             Summaries  \
# 0   WASHINGTON (AP) — Russia's invasion of Ukraine...
# 1   Vladimir Putin says he learned from his boyhoo...
# 2   KYIV, Ukraine (AP) — U.S. Treasury Secretary J...
# 3   BENGALURU, India (AP) — A meeting of finance c...
# 4   TOKYO (AP) — Japanese Prime Minister Fumio Kis...
# ..                                                ...
# 66  MARINKA, Ukraine (AP) — The hulking Russian ta...
# 67  One year after the invasion of Ukraine began, ...
# 68  BUCHA, Ukraine (AP) — In the cemetery where Ol...
# 69  VIENNA, Austria (AP) — A contentious Organizat...
# 70  NEW YORK (AP) — Emily D'Angelo made her point ...
#
#                                                 Texts            Source
# 0   FILE - Destroyed Russian armored vehicles sit ...  Associated Press
# 1   Putin's Ukraine gamble seen as biggest threat ...  Associated Press
# 2   Ukrainian President Volodymyr Zelenskyy, left,...  Associated Press
# 3   In this handout photo released by Indian Finan...  Associated Press
# 4   Japanese Prime Minister Fumio Kishida speaks d...  Associated Press
# ..                                                ...               ...
# 66  New video footage shot on Feb. 19, 2023 from t...  Associated Press
# 67  FILE - A Russian flag is held above the Olympi...  Associated Press
# 68  Ukraine war saga unfolds across the lives of 5...  Associated Press
# 69  Head of the Russian OSCE PA delegation Petr To...  Associated Press
# 70  This photo provided by Metropolitan Opera, Met...  Associated Press
#
# [70 rows x 5 columns]

# %%
asp_df = asp_df.dropna(subset=['Texts'])
asp_df
# Out:
#                                              Headings    Publication dates  \
# 0   Word war: In Russia-Ukraine war, information b...  2023-02-23 05:07:51
# 1   Putin's Ukraine gamble seen as biggest threat ...  2023-02-20 07:43:46
# 2   Yellen visits Ukraine, underscores US economic...  2023-02-27 17:52:46
# 3   G-20 meeting in India ends without consensus o...  2023-02-25 13:27:54
# 4   Japan, other G-7 leaders step up Russia sanctions  2023-02-24 12:43:36
# ..                                                ...                  ...
# 66  Ukraine: Drone video shows cost of intense fig...  2023-02-24 08:44:03
# 67  Russia's sports exile persists 1 year after in...  2023-02-22 14:26:09
# 68  Ukraine war saga unfolds across the lives of 5...  2023-02-16 08:30:40
# 69  Russian delegates defiant at hostile OSCE asse...  2023-02-24 21:03:56
# 70  Met Opera marks 1st year of Ukraine war with c...  2023-02-25 16:36:03
#
#                                             Summaries  \
# 0   WASHINGTON (AP) — Russia's invasion of Ukraine...
# 1   Vladimir Putin says he learned from his boyhoo...
# 2   KYIV, Ukraine (AP) — U.S. Treasury Secretary J...
# 3   BENGALURU, India (AP) — A meeting of finance c...
# 4   TOKYO (AP) — Japanese Prime Minister Fumio Kis...
# ..                                                ...
# 66  MARINKA, Ukraine (AP) — The hulking Russian ta...
# 67  One year after the invasion of Ukraine began, ...
# 68  BUCHA, Ukraine (AP) — In the cemetery where Ol...
# 69  VIENNA, Austria (AP) — A contentious Organizat...
# 70  NEW YORK (AP) — Emily D'Angelo made her point ...
#
#                                                 Texts            Source
# 0   FILE - Destroyed Russian armored vehicles sit ...  Associated Press
# 1   Putin's Ukraine gamble seen as biggest threat ...  Associated Press
# 2   Ukrainian President Volodymyr Zelenskyy, left,...  Associated Press
# 3   In this handout photo released by Indian Finan...  Associated Press
# 4   Japanese Prime Minister Fumio Kishida speaks d...  Associated Press
# ..                                                ...               ...
# 66  New video footage shot on Feb. 19, 2023 from t...  Associated Press
# 67  FILE - A Russian flag is held above the Olympi...  Associated Press
# 68  Ukraine war saga unfolds across the lives of 5...  Associated Press
# 69  Head of the Russian OSCE PA delegation Petr To...  Associated Press
# 70  This photo provided by Metropolitan Opera, Met...  Associated Press
#
# [69 rows x 5 columns]

# %%
asp_texts = list(asp_df['Texts'])
print(f'There are {len(asp_texts)} in the list.')
# Out:
# There are 69 in the list.

# %%
# for cleaning use the list with texts WITHOUT AUTHORS' NAMES AND INFO ON HOW TO SUPPORT!
# extract content words
asp_cleaned = clean_texts(asp_texts)
# delete the name of the source
asp_cleaned_fin = []
for text in asp_cleaned:
  text_wo_source_name = re.sub('associated press', '', text)
  asp_cleaned_fin.append(text_wo_source_name)
# Out:
# The number of texts given for cleaning 69.
# Processing...
# The number of texts cleaned is 69.

# %%
asp_df['Content words'] = asp_cleaned_fin
asp_df
# Out:
# <ipython-input-56-11ad3b18f68b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asp_df['Content words'] = asp_cleaned_fin
#                                              Headings    Publication dates  \
# 0   Word war: In Russia-Ukraine war, information b...  2023-02-23 05:07:51
# 1   Putin's Ukraine gamble seen as biggest threat ...  2023-02-20 07:43:46
# 2   Yellen visits Ukraine, underscores US economic...  2023-02-27 17:52:46
# 3   G-20 meeting in India ends without consensus o...  2023-02-25 13:27:54
# 4   Japan, other G-7 leaders step up Russia sanctions  2023-02-24 12:43:36
# ..                                                ...                  ...
# 66  Ukraine: Drone video shows cost of intense fig...  2023-02-24 08:44:03
# 67  Russia's sports exile persists 1 year after in...  2023-02-22 14:26:09
# 68  Ukraine war saga unfolds across the lives of 5...  2023-02-16 08:30:40
# 69  Russian delegates defiant at hostile OSCE asse...  2023-02-24 21:03:56
# 70  Met Opera marks 1st year of Ukraine war with c...  2023-02-25 16:36:03
#
#                                             Summaries  \
# 0   WASHINGTON (AP) — Russia's invasion of Ukraine...
# 1   Vladimir Putin says he learned from his boyhoo...
# 2   KYIV, Ukraine (AP) — U.S. Treasury Secretary J...
# 3   BENGALURU, India (AP) — A meeting of finance c...
# 4   TOKYO (AP) — Japanese Prime Minister Fumio Kis...
# ..                                                ...
# 66  MARINKA, Ukraine (AP) — The hulking Russian ta...
# 67  One year after the invasion of Ukraine began, ...
# 68  BUCHA, Ukraine (AP) — In the cemetery where Ol...
# 69  VIENNA, Austria (AP) — A contentious Organizat...
# 70  NEW YORK (AP) — Emily D'Angelo made her point ...
#
#                                                 Texts            Source  \
# 0   FILE - Destroyed Russian armored vehicles sit ...  Associated Press
# 1   Putin's Ukraine gamble seen as biggest threat ...  Associated Press
# 2   Ukrainian President Volodymyr Zelenskyy, left,...  Associated Press
# 3   In this handout photo released by Indian Finan...  Associated Press
# 4   Japanese Prime Minister Fumio Kishida speaks d...  Associated Press
# ..                                                ...               ...
# 66  New video footage shot on Feb. 19, 2023 from t...  Associated Press
# 67  FILE - A Russian flag is held above the Olympi...  Associated Press
# 68  Ukraine war saga unfolds across the lives of 5...  Associated Press
# 69  Head of the Russian OSCE PA delegation Petr To...  Associated Press
# 70  This photo provided by Metropolitan Opera, Met...  Associated Press
#
#                                         Content words
# 0   file destroy russian armored vehicle sit outsk...
# 1   putin ukraine gamble see big threat rule vladi...
# 2   ukrainian president volodymyr zelenskyy leave ...
# 3   handout photo release indian finance ministry ...
# 4   japanese prime minister fumio kishida speak pr...
# ..                                                ...
# 66  new video footage shoot feb air drone  show pa...
# 67  file russian flag hold olympic ring adler aren...
# 68  ukraine war saga unfold life friend bucha ukra...
# 69  head russian osce pa delegation petr tolstoy a...
# 70  photo provide metropolitan opera meet music di...
#
# [69 rows x 6 columns]

# %% [markdown]
# ## 1.2.3. High credibility sources dataset

# %%
hc_df = pd.concat([n_df, asp_df, fp_df])
hc_df['Label'] = 0
hc_df
# Out:
#                                                Headings  \
# 0     Ten Kazakhstan nationals charged with particip...
# 1     Ukraine’s Defence Minister: ‘total losses of U...
# 2                                           Putin’s MPs
# 3        Vladimir Kara-Murza: portrait of Putin’s enemy
# 4     Russian singer-songwriter Semyon Slepakov, jou...
# ...                                                 ...
# 2288  Polish MiG-29 Jets for Ukraine Is a Deeply Fla...
# 2289          Russia and China Threats Are Not the Same
# 2290  How Europe Can Slash Fossil Fuels and Frustrat...
# 2291     Moscow Strikes Back at Countries That Cross It
# 2292                                 The Scots Question
#
#             Publication dates   Summaries  \
# 0     04:42 PM, 16 April 2023  No Summary
# 1     02:25 PM, 16 April 2023  No Summary
# 2     10:44 AM, 16 April 2023  No Summary
# 3     01:40 PM, 15 April 2023  No Summary
# 4     08:12 PM, 14 April 2023  No Summary
# ...                       ...         ...
# 2288      2022-03-14 15:19:10         NaN
# 2289      2022-10-13 15:44:14         NaN
# 2290      2022-03-10 09:39:12         NaN
# 2291      2022-04-18 13:15:20         NaN
# 2292      2022-06-29 14:47:21         NaN
#
#                                                   Texts                Source  \
# 0     Kazakhstan’s National Security Committee is in...  Novaya Gazeta Europe
# 1     Ukraine’s Defence Minister Oleksiy Reznikov ha...  Novaya Gazeta Europe
# 2     Back in 2003, former Duma speaker Boris Gryzlo...  Novaya Gazeta Europe
# 3     Foundation\nVladimir Kara-Murza was born into ...  Novaya Gazeta Europe
# 4     Russian singer-songwriter Semyon Slepakov, jou...  Novaya Gazeta Europe
# ...                                                 ...                   ...
# 2288  Successful security assistance begins with an ...        Foreign Policy
# 2289  If you would like to receive Situation Report ...        Foreign Policy
# 2290  Yet, in the first two weeks of Russia’s invasi...        Foreign Policy
# 2291  “Mr. President, we are sure that today’s speak...        Foreign Policy
# 2292  That Scots is so embedded in everyday communic...        Foreign Policy
#
#                                           Content words  Label
# 0     kazakhstan national security committee investi...      0
# 1     ukraine defence minister oleksiy reznikov spea...      0
# 2     duma speaker boris gryzlov coin catchphrase pa...      0
# 3     foundation vladimir kara murza bear family res...      0
# 4     russian singer songwriter semyon slepakov jour...      0
# ...                                                 ...    ...
# 2288  successful security assistance begin identify ...      0
# 2289  like receive situation report inbox thursday s...      0
# 2290  week russia invasion ukraine eu likely pay upw...      0
# 2291  mr president sure today speaker address lot ki...      0
# 2292  scot embed everyday communication give rise co...      0
#
# [3018 rows x 7 columns]

# %%
all_news_df = pd.concat([lc_df, hc_df])
all_news_df
# Out:
#                                                Headings    Publication dates  \
# 0     US' inspector general for Afghanistan warns ag...  2023-02-26 17:54:00
# 1     US presidential hopeful calls for end to Ukrai...  2023-02-26 17:11:00
# 2      Ukraine’s neighbor speaks out on NATO membership  2023-02-26 15:01:00
# 3     Defense minister explains conditions for Russi...  2023-02-26 14:26:00
# 4                    Thousands rally for peace in Italy  2023-02-26 14:25:00
# ...                                                 ...                  ...
# 2288  Polish MiG-29 Jets for Ukraine Is a Deeply Fla...  2022-03-14 15:19:10
# 2289          Russia and China Threats Are Not the Same  2022-10-13 15:44:14
# 2290  How Europe Can Slash Fossil Fuels and Frustrat...  2022-03-10 09:39:12
# 2291     Moscow Strikes Back at Countries That Cross It  2022-04-18 13:15:20
# 2292                                 The Scots Question  2022-06-29 14:47:21
#
#                                               Summaries  \
# 0     Failure to implement rigid oversight measures ...
# 1     The US should focus on China and Taiwan instea...
# 2     The possibility of joining NATO isn’t being ra...
# 3     Potential Russian military advances in Ukraine...
# 4     Several thousands have taken to the streets of...
# ...                                                 ...
# 2288                                                NaN
# 2289                                                NaN
# 2290                                                NaN
# 2291                                                NaN
# 2292                                                NaN
#
#                                                   Texts          Source  \
# 0     Washington has been the largest financial cont...    Russia Today
# 1     Washington should focus on countering China an...    Russia Today
# 2     Moldova must be able to protect itself, but no...    Russia Today
# 3     A widening of the military operation depends o...    Russia Today
# 4     Demonstrators in the cities of Genoa and Milan...    Russia Today
# ...                                                 ...             ...
# 2288  Successful security assistance begins with an ...  Foreign Policy
# 2289  If you would like to receive Situation Report ...  Foreign Policy
# 2290  Yet, in the first two weeks of Russia’s invasi...  Foreign Policy
# 2291  “Mr. President, we are sure that today’s speak...  Foreign Policy
# 2292  That Scots is so embedded in everyday communic...  Foreign Policy
#
#                                           Content words  Label
# 0     washington large financial contributor ukraine...      1
# 1     washington focus counter china tackle taiwan i...      1
# 2     moldova able protect join lead military bloc p...      1
# 3     widening military operation depend weaponry ki...      1
# 4     demonstrator city genoa milan demand end weapo...      1
# ...                                                 ...    ...
# 2288  successful security assistance begin identify ...      0
# 2289  like receive situation report inbox thursday s...      0
# 2290  week russia invasion ukraine eu likely pay upw...      0
# 2291  mr president sure today speaker address lot ki...      0
# 2292  scot embed everyday communication give rise co...      0
#
# [6579 rows x 7 columns]

# %%
all_news_df.to_csv('all_news_final_apr.csv', index=False)

# %% [markdown]
# # 2. Feature extraction

# %%
path = '/content/drive/MyDrive/final_df.csv'
all_news_df = pd.read_csv(path)
all_news_df
# Out:
#                                                Headings    Publication dates  \
# 0     US' inspector general for Afghanistan warns ag...  2023-02-26 17:54:00
# 1     US presidential hopeful calls for end to Ukrai...  2023-02-26 17:11:00
# 2      Ukraine’s neighbor speaks out on NATO membership  2023-02-26 15:01:00
# 3     Defense minister explains conditions for Russi...  2023-02-26 14:26:00
# 4                    Thousands rally for peace in Italy  2023-02-26 14:25:00
# ...                                                 ...                  ...
# 6572       Moldova Feels the Shock Waves of Putin’s War  2022-04-26 13:40:09
# 6573  Polish MiG-29 Jets for Ukraine Is a Deeply Fla...  2022-03-14 15:19:10
# 6574          Russia and China Threats Are Not the Same  2022-10-13 15:44:14
# 6575  How Europe Can Slash Fossil Fuels and Frustrat...  2022-03-10 09:39:12
# 6576     Moscow Strikes Back at Countries That Cross It  2022-04-18 13:15:20
#
#                                               Summaries  \
# 0     Failure to implement rigid oversight measures ...
# 1     The US should focus on China and Taiwan instea...
# 2     The possibility of joining NATO isn’t being ra...
# 3     Potential Russian military advances in Ukraine...
# 4     Several thousands have taken to the streets of...
# ...                                                 ...
# 6572                                                NaN
# 6573                                                NaN
# 6574                                                NaN
# 6575                                                NaN
# 6576                                                NaN
#
#                                                   Texts          Source  \
# 0     Washington has been the largest financial cont...    Russia Today
# 1     Washington should focus on countering China an...    Russia Today
# 2     Moldova must be able to protect itself, but no...    Russia Today
# 3     A widening of the military operation depends o...    Russia Today
# 4     Demonstrators in the cities of Genoa and Milan...    Russia Today
# ...                                                 ...             ...
# 6572  In light of the struggles that have beset the ...  Foreign Policy
# 6573  Successful security assistance begins with an ...  Foreign Policy
# 6574  If you would like to receive Situation Report ...  Foreign Policy
# 6575  Yet, in the first two weeks of Russia’s invasi...  Foreign Policy
# 6576  “Mr. President, we are sure that today’s speak...  Foreign Policy
#
#                                           Content words  Label  \
# 0     washington large financial contributor ukraine...      1
# 1     washington focus counter china tackle taiwan i...      1
# 2     moldova able protect join lead military bloc p...      1
# 3     widening military operation depend weaponry ki...      1
# 4     demonstrator city genoa milan demand end weapo...      1
# ...                                                 ...    ...
# 6572  light struggle beset russian military campaign...      0
# 6573  successful security assistance begin identify ...      0
# 6574  like receive situation report inbox thursday s...      0
# 6575  week russia invasion ukraine eu likely pay upw...      0
# 6576  mr president sure today speaker address lot ki...      0
#
#                                         Adjectives only  \
# 0     large financial robust foreign special appoint...
# 1     ongoing prolong long possible presidential ear...
# 2     able military parliamentary official large pri...
# 3     military military potential western main legis...
# 4     italian national participant local medium coll...
# ...                                                 ...
# 6572  light russian military far skeptical ukrainian...
# 6573  successful ukrainian unable russian absent pub...
# 6574  national national welcome clear sigh minor cle...
# 6575  actual essential russian offensive quiet russi...
# 6576  sure contentious future long armed national ou...
#
#                             Adjectives and adverbs only  \
# 0     large financial robust foreign special appoint...
# 1     instead ongoing allegedly prolong long possibl...
# 2     able military parliamentary official previousl...
# 3     military military potential directly western m...
# 4     italian national nearly participant local medi...
# ...                                                 ...
# 6572  light russian military far skeptical west ukra...
# 6573  successful ukrainian unable russian absent pub...
# 6574  national newly national welcome closely clear ...
# 6575  likely actual essential russian offensive quie...
# 6576  sure contentious future instead long armed nat...
#
#                                     Function words only  \
# 0     has been the to in its with must be in and fro...
# 1     should on and the the is being by in the betwe...
# 2     must be itself but by the its the of is being ...
# 3     a of the on the from the has has the for a of ...
# 4     in the of and are an to to up for in the of an...
# ...                                                 ...
# 6572  in of the that have the in are can along the t...
# 6573  with an what is the are or are they for their ...
# 6574  you would in your every up and to what on for ...
# 6575  in the of of the upwards of to for what is in ...
# 6576  we are will of to you but in you are with some...
#
#                                             Punctuation  \
# 0     , , ’ ( ) . , ’ , “ ” – “ . ” . “ , – , , , ” ...
# 1     , “ ” , , . . , “ ” . . “ : . . : ‘ ’ , ‘ ’ , ...
# 2     , - , , . “ ” . “ , , , ” . , , “ ” . “ , ” , ...
# 3     , , . “ , ” ‘ . . . ’ , , . “ , ” . “ , . . ” ...
# 4     . - , , . , . ( ) , “ , . ” “ ” “ , - . ” , . ...
# ...                                                 ...
# 6572  , - , . , . , , , - - — — “ - . ” , , , . , , ...
# 6573  : ? , - ? ? , . , . , . - . , - . : “ . . , . ...
# 6574  , . , . : , , . ! , . . , , ( ) , . ! , . . , ...
# 6575  , , . . , . . . - , , . , . , , , , , , , , . ...
# 6576  “ , , ” . “ , , . . ” , , , , , . , ( ) . , ( ...
#
#       Polarity scores for adjectives and adverbs  \
# 0                                      -0.031027
# 1                                       0.056622
# 2                                       0.085969
# 3                                       0.004444
# 4                                       0.103306
# ...                                          ...
# 6572                                    0.026159
# 6573                                    0.053228
# 6574                                    0.059497
# 6575                                    0.069159
# 6576                                    0.018018
#
#                                              Verbs only  \
# 0     prevent undermine assist oversee extend admit ...
# 1     play seek announce want invade think look ukra...
# 2     say join consider say hint speak want tell rep...
# 3     widening depend get say widening explain tie d...
# 4     end turn left breach send draw organize take s...
# ...                                                 ...
# 6572  beset push say renew speak send seek take spur...
# 6573  begin identify achieve intercept risk fight fl...
# 6574  receive release offer condemn grab follow anti...
# 6575  pay translate come undermine carry move accele...
# 6576  try skirt say tell try pretend duque receive a...
#
#                                              Nouns only
# 0     contributor conflict safeguard place fraud cor...
# 1     issue conflict hostility entrepreneur candidac...
# 2     protect join lead speaker possibility speaker ...
# 3     operation outline condition advance arm delive...
# 4     weapon supply kiev people peace demonstration ...
# ...                                                 ...
# 6572  struggle campaign analyst concern goal create ...
# 6573  security assistance requirement battlefield re...
# 6574  situation report tap day diving security strat...
# 6575  week fossil fuel response mechanism action red...
# 6576  today speaker address lot kind word issue frie...
#
# [6577 rows x 14 columns]

# %%
df = all_news_df

# %% [markdown]
# ## 2.1. Adjectives

# %%
# check for missing values
if df['Content words'].isnull().any():
    # print the missing values in column A
    print(df['Content words'][df['Content words'].isnull()])
else:
    print('No missing values in a column.')
# Out:
# No missing values in a column.

# %%
df = df.drop(2445)
# check for missing values
if df['Content words'].isnull().any():
    # print the missing values in column A
    print(df['Content words'][df['Content words'].isnull()])
else:
    print('No missing values in a column.')
# Out:
# No missing values in a column.

# %%
# check if all the elements in a list are the same type
# if not, delete the ones that are inconsistent
string_type = type(df.loc[0, 'Content words'])

# check if all elements are of the same type
for index, row in df.iterrows():
    if type(row['Content words']) != string_type:
        print(f"Type {type(row['Content words'])} differs from type {string_type}.")
        break
else:
    print(f"All elements in a column are of type {string_type}.")
# Out:
# All elements in a column are of type <class 'str'>.

# %%
adjectives = []
for text in list(df['Content words']):
  doc = nlp(text)
  adj = [token.text for token in doc if token.pos_ == 'ADJ']
  adjectives.append(adj)

print('All done!')
print('The number of texts processed is', len(adjectives))
print()
print('The example:')
print(adjectives[0])

# %%
adjectives_joint = []
for text in adjectives:
  adj_jnt = ' '.join(text)
  adjectives_joint.append(adj_jnt)

print(adjectives_joint[0])
df['Adjectives only'] = adjectives_joint
# Out:
# large financial robust foreign special appoint military significant allocate foreign bad steal accomplish intend ukrainian corrupt ukrainian necessary average ukrainian similar afghan recent military financial ukraine special ukrainian

# %% [markdown]
# ## 2.2. Adjectives and adverbs

# %%
adjectives_and_adverbs = []
for text in list(df['Content words']):
  doc = nlp(text)
  adj_adv = [token.text for token in doc if token.pos_ in ['ADJ', 'ADV']]
  adjectives_and_adverbs.append(adj_adv)

print('All done!')
print('The number of texts processed is', len(adjectives_and_adverbs))
print()
print('The example:')
print(adjectives_and_adverbs[0])
# Out:
# All done!
# The number of texts processed is 6578
#
# The example:
# ['large', 'financial', 'robust', 'foreign', 'special', 'appoint', 'military', 'significant', 'principally', 'allocate', 'severely', 'foreign', 'bad', 'steal', 'accomplish', 'intend', 'ukrainian', 'corrupt', 'ukrainian', 'necessary', 'average', 'ukrainian', 'similar', 'afghan', 'recent', 'military', 'financial', 'ukraine', 'special', 'ukrainian']

# %%
adj_adv_joint = []
for text in adjectives_and_adverbs:
  adj_adv_jnt = ' '.join(text)
  adj_adv_joint.append(adj_adv_jnt)

print(adj_adv_joint[0])
df['Adjectives and adverbs only'] = adj_adv_joint
# Out:
# large financial robust foreign special appoint military significant principally allocate severely foreign bad steal accomplish intend ukrainian corrupt ukrainian necessary average ukrainian similar afghan recent military financial ukraine special ukrainian

# %%
df
# Out:
#                                                Headings    Publication dates  \
# 0     US' inspector general for Afghanistan warns ag...  2023-02-26 17:54:00
# 1     US presidential hopeful calls for end to Ukrai...  2023-02-26 17:11:00
# 2      Ukraine’s neighbor speaks out on NATO membership  2023-02-26 15:01:00
# 3     Defense minister explains conditions for Russi...  2023-02-26 14:26:00
# 4                    Thousands rally for peace in Italy  2023-02-26 14:25:00
# ...                                                 ...                  ...
# 6574  Polish MiG-29 Jets for Ukraine Is a Deeply Fla...  2022-03-14 15:19:10
# 6575          Russia and China Threats Are Not the Same  2022-10-13 15:44:14
# 6576  How Europe Can Slash Fossil Fuels and Frustrat...  2022-03-10 09:39:12
# 6577     Moscow Strikes Back at Countries That Cross It  2022-04-18 13:15:20
# 6578                                 The Scots Question  2022-06-29 14:47:21
#
#                                               Summaries  \
# 0     Failure to implement rigid oversight measures ...
# 1     The US should focus on China and Taiwan instea...
# 2     The possibility of joining NATO isn’t being ra...
# 3     Potential Russian military advances in Ukraine...
# 4     Several thousands have taken to the streets of...
# ...                                                 ...
# 6574                                                NaN
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
#
#                                                   Texts          Source  \
# 0     Washington has been the largest financial cont...    Russia Today
# 1     Washington should focus on countering China an...    Russia Today
# 2     Moldova must be able to protect itself, but no...    Russia Today
# 3     A widening of the military operation depends o...    Russia Today
# 4     Demonstrators in the cities of Genoa and Milan...    Russia Today
# ...                                                 ...             ...
# 6574  Successful security assistance begins with an ...  Foreign Policy
# 6575  If you would like to receive Situation Report ...  Foreign Policy
# 6576  Yet, in the first two weeks of Russia’s invasi...  Foreign Policy
# 6577  “Mr. President, we are sure that today’s speak...  Foreign Policy
# 6578  That Scots is so embedded in everyday communic...  Foreign Policy
#
#                                           Content words  Label  \
# 0     washington large financial contributor ukraine...      1
# 1     washington focus counter china tackle taiwan i...      1
# 2     moldova able protect join lead military bloc p...      1
# 3     widening military operation depend weaponry ki...      1
# 4     demonstrator city genoa milan demand end weapo...      1
# ...                                                 ...    ...
# 6574  successful security assistance begin identify ...      0
# 6575  like receive situation report inbox thursday s...      0
# 6576  week russia invasion ukraine eu likely pay upw...      0
# 6577  mr president sure today speaker address lot ki...      0
# 6578  scot embed everyday communication give rise co...      0
#
#                                         Adjectives only  \
# 0     large financial robust foreign special appoint...
# 1     ongoing prolong long possible presidential ear...
# 2     able military parliamentary official large pri...
# 3     military military potential western main legis...
# 4     italian national participant local medium coll...
# ...                                                 ...
# 6574  successful ukrainian unable russian absent pub...
# 6575  national national welcome clear sigh minor cle...
# 6576  actual essential russian offensive quiet russi...
# 6577  sure contentious future long armed national ou...
# 6578  everyday regional derivative scottish second b...
#
#                             Adjectives and adverbs only
# 0     large financial robust foreign special appoint...
# 1     instead ongoing allegedly prolong long possibl...
# 2     able military parliamentary official previousl...
# 3     military military potential directly western m...
# 4     italian national nearly participant local medi...
# ...                                                 ...
# 6574  successful ukrainian unable russian absent pub...
# 6575  national newly national welcome closely clear ...
# 6576  likely actual essential russian offensive quie...
# 6577  sure contentious future instead long armed nat...
# 6578  everyday regional derivative scottish second b...
#
# [6578 rows x 9 columns]

# %% [markdown]
# ## 2.3. Funciton words and punctuation

# %%
# punktuation and function words extraction from raw texts
punctuation = []
function_words = []
function_word_tags = {"DET", "PRON", "ADP", "CCONJ", "AUX"}

for text in df['Texts']:
  doc = nlp(text)
  punct = [token.text for token in doc if token.is_punct]
  punctuation.append(punct)

  fw = [token.text for token in doc if token.pos_ in function_word_tags]
  function_words.append(fw)

fw_joint = []
for text in function_words:
  fw_jnt = ' '.join(text)
  fw_joint.append(fw_jnt)

punct_joint = []
for text in punctuation:
  p_jnt = ' '.join(text)
  punct_joint.append(p_jnt)

fw_joint_low = []
for text in fw_joint:
  lowered = text.lower()
  fw_joint_low.append(lowered)

df['Function words only'] = fw_joint_low
df['Punctuation'] = punct_joint
df

# %% [markdown]
# ## 2.4. Verbs

# %%
verbs = []
for text in list(df['Content words']):
  doc = nlp(text)
  verb = [token.text for token in doc if token.pos_ == 'VERB']
  verbs.append(verb)

print('All done!')
print('The number of texts processed is', len(verbs))
print()
print('The example:')
print(verbs[0])

verbs_joint = []
for text in verbs:
  vrb_jnt = ' '.join(text)
  verbs_joint.append(vrb_jnt)

print(verbs_joint[0])
df['Verbs only'] = verbs_joint
# Out:
# All done!
# The number of texts processed is 6578
#
# The example:
# ['prevent', 'undermine', 'assist', 'oversee', 'extend', 'admit', 'rebuilding', 'predict', 'learn', 'limit', 'gets', 'provide', 'win', 'say', 'explain', 'bind', 'steal', 'add', 'intend', 'cite', 'conclude', 'lose', 'continue', 'announce', 'impose', 'send', 'say', 'call', 'oversee', 'find']
# prevent undermine assist oversee extend admit rebuilding predict learn limit gets provide win say explain bind steal add intend cite conclude lose continue announce impose send say call oversee find

# %%
# delete the article about Scotland
df = df.drop(6578)

# %% [markdown]
# ## 2.5. Polarity scores for adjectives and adverbs

# %%
# sentiment analysis with textblob
from textblob import TextBlob

polarity_scores = []
for text in df['Adjectives and adverbs only']:
  blob = TextBlob(text)
  polarity = blob.sentiment.polarity
  polarity_scores.append(polarity)
print(len(polarity_scores))
df['Polarity scores for adjectives and adverbs'] = polarity_scores
# Out:
# 6578

# %% [markdown]
# ## 2.6. Nouns

# %%
nouns = []
for text in list(df['Content words']):
  doc = nlp(text)
  noun = [token.text for token in doc if token.pos_ == 'NOUN']
  nouns.append(noun)

print('All done!')
print('The number of texts processed is', len(nouns))
print()
print('The example:')
print(nouns[0])

nouns_joint = []
for text in nouns:
  nn_jnt = ' '.join(text)
  nouns_joint.append(nn_jnt)

print(nouns_joint[0])
df['Nouns only'] = nouns_joint
# Out:
# All done!
# The number of texts processed is 6577
#
# The example:
# ['contributor', 'conflict', 'safeguard', 'place', 'fraud', 'corruption', 'aid', 'package', 'conflict', 'role', 'presence', 'country', 'fund', 'divert', 'failure', 'mistake', 'impact', 'assistance', 'outcome', 'assistance', 'divert', 'way', 'purpose', 'case', 'weapon', 'money', 'wastage', 'element', 'host', 'government', 'government', 'money', 'oversight', 'waste', 'impact', 'aid', 'lead', 'loss', 'support', 'measure', 'experience', 'soldier', 'police', 'officer', 'confidence', 'government', 'hand', 'observation', 'corruption', 'increase', 'aid', 'package', 'month', 'year', 'anniversary', 'launch', 'operation', 'country', 'aid', 'package', 'sanction', 'tariff', 'increase', 'rubber', 'stamp', 'assistance', 'month', 'plan', 'committee', 'track', 'asset', 'exercise', 'inspector', 'appoint', 'aid', 'report', 'month', 'leader', 'fire', 'government', 'official', 'engage', 'bribery', 'corruption']
# contributor conflict safeguard place fraud corruption aid package conflict role presence country fund divert failure mistake impact assistance outcome assistance divert way purpose case weapon money wastage element host government government money oversight waste impact aid lead loss support measure experience soldier police officer confidence government hand observation corruption increase aid package month year anniversary launch operation country aid package sanction tariff increase rubber stamp assistance month plan committee track asset exercise inspector appoint aid report month leader fire government official engage bribery corruption

# %%
df
# Out:
#                                                Headings    Publication dates  \
# 0     US' inspector general for Afghanistan warns ag...  2023-02-26 17:54:00
# 1     US presidential hopeful calls for end to Ukrai...  2023-02-26 17:11:00
# 2      Ukraine’s neighbor speaks out on NATO membership  2023-02-26 15:01:00
# 3     Defense minister explains conditions for Russi...  2023-02-26 14:26:00
# 4                    Thousands rally for peace in Italy  2023-02-26 14:25:00
# ...                                                 ...                  ...
# 6573       Moldova Feels the Shock Waves of Putin’s War  2022-04-26 13:40:09
# 6574  Polish MiG-29 Jets for Ukraine Is a Deeply Fla...  2022-03-14 15:19:10
# 6575          Russia and China Threats Are Not the Same  2022-10-13 15:44:14
# 6576  How Europe Can Slash Fossil Fuels and Frustrat...  2022-03-10 09:39:12
# 6577     Moscow Strikes Back at Countries That Cross It  2022-04-18 13:15:20
#
#                                               Summaries  \
# 0     Failure to implement rigid oversight measures ...
# 1     The US should focus on China and Taiwan instea...
# 2     The possibility of joining NATO isn’t being ra...
# 3     Potential Russian military advances in Ukraine...
# 4     Several thousands have taken to the streets of...
# ...                                                 ...
# 6573                                                NaN
# 6574                                                NaN
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
#
#                                                   Texts          Source  \
# 0     Washington has been the largest financial cont...    Russia Today
# 1     Washington should focus on countering China an...    Russia Today
# 2     Moldova must be able to protect itself, but no...    Russia Today
# 3     A widening of the military operation depends o...    Russia Today
# 4     Demonstrators in the cities of Genoa and Milan...    Russia Today
# ...                                                 ...             ...
# 6573  In light of the struggles that have beset the ...  Foreign Policy
# 6574  Successful security assistance begins with an ...  Foreign Policy
# 6575  If you would like to receive Situation Report ...  Foreign Policy
# 6576  Yet, in the first two weeks of Russia’s invasi...  Foreign Policy
# 6577  “Mr. President, we are sure that today’s speak...  Foreign Policy
#
#                                           Content words  Label  \
# 0     washington large financial contributor ukraine...      1
# 1     washington focus counter china tackle taiwan i...      1
# 2     moldova able protect join lead military bloc p...      1
# 3     widening military operation depend weaponry ki...      1
# 4     demonstrator city genoa milan demand end weapo...      1
# ...                                                 ...    ...
# 6573  light struggle beset russian military campaign...      0
# 6574  successful security assistance begin identify ...      0
# 6575  like receive situation report inbox thursday s...      0
# 6576  week russia invasion ukraine eu likely pay upw...      0
# 6577  mr president sure today speaker address lot ki...      0
#
#                                         Adjectives only  \
# 0     large financial robust foreign special appoint...
# 1     ongoing prolong long possible presidential ear...
# 2     able military parliamentary official large pri...
# 3     military military potential western main legis...
# 4     italian national participant local medium coll...
# ...                                                 ...
# 6573  light russian military far skeptical ukrainian...
# 6574  successful ukrainian unable russian absent pub...
# 6575  national national welcome clear sigh minor cle...
# 6576  actual essential russian offensive quiet russi...
# 6577  sure contentious future long armed national ou...
#
#                             Adjectives and adverbs only  \
# 0     large financial robust foreign special appoint...
# 1     instead ongoing allegedly prolong long possibl...
# 2     able military parliamentary official previousl...
# 3     military military potential directly western m...
# 4     italian national nearly participant local medi...
# ...                                                 ...
# 6573  light russian military far skeptical west ukra...
# 6574  successful ukrainian unable russian absent pub...
# 6575  national newly national welcome closely clear ...
# 6576  likely actual essential russian offensive quie...
# 6577  sure contentious future instead long armed nat...
#
#                                     Function words only  \
# 0     has been the to in its with must be in and fro...
# 1     should on and the the is being by in the betwe...
# 2     must be itself but by the its the of is being ...
# 3     a of the on the from the has has the for a of ...
# 4     in the of and are an to to up for in the of an...
# ...                                                 ...
# 6573  in of the that have the in are can along the t...
# 6574  with an what is the are or are they for their ...
# 6575  you would in your every up and to what on for ...
# 6576  in the of of the upwards of to for what is in ...
# 6577  we are will of to you but in you are with some...
#
#                                             Punctuation  \
# 0     , , ’ ( ) . , ’ , “ ” – “ . ” . “ , – , , , ” ...
# 1     , “ ” , , . . , “ ” . . “ : . . : ‘ ’ , ‘ ’ , ...
# 2     , - , , . “ ” . “ , , , ” . , , “ ” . “ , ” , ...
# 3     , , . “ , ” ‘ . . . ’ , , . “ , ” . “ , . . ” ...
# 4     . - , , . , . ( ) , “ , . ” “ ” “ , - . ” , . ...
# ...                                                 ...
# 6573  , - , . , . , , , - - — — “ - . ” , , , . , , ...
# 6574  : ? , - ? ? , . , . , . - . , - . : “ . . , . ...
# 6575  , . , . : , , . ! , . . , , ( ) , . ! , . . , ...
# 6576  , , . . , . . . - , , . , . , , , , , , , , . ...
# 6577  “ , , ” . “ , , . . ” , , , , , . , ( ) . , ( ...
#
#       Polarity scores for adjectives and adverbs  \
# 0                                      -0.031027
# 1                                       0.056622
# 2                                       0.085969
# 3                                       0.004444
# 4                                       0.103306
# ...                                          ...
# 6573                                    0.026159
# 6574                                    0.053228
# 6575                                    0.059497
# 6576                                    0.069159
# 6577                                    0.018018
#
#                                              Verbs only  \
# 0     prevent undermine assist oversee extend admit ...
# 1     play seek announce want invade think look ukra...
# 2     say join consider say hint speak want tell rep...
# 3     widening depend get say widening explain tie d...
# 4     end turn left breach send draw organize take s...
# ...                                                 ...
# 6573  beset push say renew speak send seek take spur...
# 6574  begin identify achieve intercept risk fight fl...
# 6575  receive release offer condemn grab follow anti...
# 6576  pay translate come undermine carry move accele...
# 6577  try skirt say tell try pretend duque receive a...
#
#                                              Nouns only
# 0     contributor conflict safeguard place fraud cor...
# 1     issue conflict hostility entrepreneur candidac...
# 2     protect join lead speaker possibility speaker ...
# 3     operation outline condition advance arm delive...
# 4     weapon supply kiev people peace demonstration ...
# ...                                                 ...
# 6573  struggle campaign analyst concern goal create ...
# 6574  security assistance requirement battlefield re...
# 6575  situation report tap day diving security strat...
# 6576  week fossil fuel response mechanism action red...
# 6577  today speaker address lot kind word issue frie...
#
# [6577 rows x 14 columns]

# %%
df.to_csv('final_df.csv', index=False)
